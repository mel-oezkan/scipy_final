# %% [markdown]
# # Visualizations of the Scrapped Data

# %%
from src.utils.visualizer import test_function 
from src.utils.visualizer import show_samples
# Out:
# Collecting selenium
#   Downloading selenium-3.141.0-py2.py3-none-any.whl (904 kB)
# Requirement already satisfied: urllib3 in c:\users\konst\anaconda3\envs\scipy\lib\site-packages (from selenium) (1.26.4)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-91eed73af730> in <module>
#       1 get_ipython().system('pip install selenium')
# ----> 2 from src.utils.visualizer import test_function
#       3 from src.utils.visualizer import show_samples
#
# ~\Documents\Scientific_Python\Final_project\scipy_final\src\utils\visualizer.py in <module>
#       3 import pandas as pd
#       4
# ----> 5 from src.scrapper.WebScrapper import Scrapper
#       6
#       7 def test_function():
#
# ~\Documents\Scientific_Python\Final_project\scipy_final\src\scrapper\WebScrapper.py in <module>
#       1 import selenium
#       2 from src.scrapper.IdMaps import Mapper
# ----> 3 from src.scrapper.ConfigParser import Config
#       4 from sys import platform
#       5
#
# ~\Documents\Scientific_Python\Final_project\scipy_final\src\scrapper\ConfigParser.py in <module>
#       1 from src.scrapper.IdMaps import Mapper
# ----> 2 import yaml
#       3
#       4
#       5 class Config:
#
# ModuleNotFoundError: No module named 'yaml'

# %%
test_function()

# %% [markdown]
# ## Examplary images from the dataset

# %%
show_samples("data/full_data.csv")
# Out:
# /home/melih/Documents/Uni/s4/SciPy/scipy_final

# %% [markdown]
# ## Average Prices for different types of Clothing
