# %% [markdown]
# # Visualizations of the Scrapped Data

# %%
# !pip install imageio
from src.utils.visualizer import test_function 
from src.utils.visualizer import show_samples
# Out:
# Requirement already satisfied: imageio in c:\users\konst\anaconda3\envs\scipy\lib\site-packages (2.9.0)
# Requirement already satisfied: pillow in c:\users\konst\anaconda3\envs\scipy\lib\site-packages (from imageio) (8.2.0)
# Requirement already satisfied: numpy in c:\users\konst\anaconda3\envs\scipy\lib\site-packages (from imageio) (1.20.2)

# %%
test_function()

# %% [markdown]
# ## Examplary images from the dataset

# %%
show_samples("data/full_data.csv")

# %% [markdown]
# ## Average Prices for different types of Clothing

# %%
# !python run.py --mode scrapper --config "config.yaml" --max_page 12 --ds_name "test"
